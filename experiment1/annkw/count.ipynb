# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import datetime as dt
from datetime import datetime as dtdt
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import ticker
import matplotlib.dates as mdates
from matplotlib.dates import date2num
from matplotlib.dates import DateFormatter
import seaborn as sns
sns.set()

# %%
path = "/Users/iomacbookair2/Documents/lab/DEIM2023/experiment1/annkw/220116_annkw.csv"
df = pd.read_csv((path))
df['created_at'] = pd.to_datetime(df['created_at'])
df.sort_values(by = 'created_at', ascending = True, inplace = True)
df = df.reset_index(drop=True)
df
# Out:
#                created_at                                               text
# 0     2022-01-16 01:00:00                                             #annkw
# 1     2022-01-16 01:00:00                                             #annkw
# 2     2022-01-16 01:00:00                                             #annkw
# 3     2022-01-16 01:00:00                                             #annkw
# 4     2022-01-16 01:00:00                                  ニチレイプレゼンツ！！#annkw
# ...                   ...                                                ...
# 11260 2022-01-16 03:04:15                   死んやめがなかったのは今週は仕方ないな #annkw #jolf
# 11261 2022-01-16 03:04:27         最高にトゥースな夜だった#annkw https://t.co/liLMmhjyw1
# 11262 2022-01-16 03:04:41                     動画までツイートしてくれるの珍しいありがてえ… #annkw
# 11263 2022-01-16 03:04:52                               ミッフィーちゃん夢股ディオス#annkw
# 11264 2022-01-16 03:04:56  ----商品価格:4,180円----✨本日のトレンド✨#SixTONESANN火山噴火トン...
#
# [11265 rows x 2 columns]

# %%
c_df = df.set_index('created_at').resample('T').count()
cnt = pd.DataFrame(
    {'created_at' : c_df.index.strftime('%Y-%m-%d %H:%M:%S'), 'tweet' : c_df['text'].values})
cnt
# Out:
#               created_at  tweet
# 0    2022-01-16 01:00:00    862
# 1    2022-01-16 01:01:00    309
# 2    2022-01-16 01:02:00    122
# 3    2022-01-16 01:03:00    213
# 4    2022-01-16 01:04:00    237
# ..                   ...    ...
# 120  2022-01-16 03:00:00     76
# 121  2022-01-16 03:01:00     33
# 122  2022-01-16 03:02:00     26
# 123  2022-01-16 03:03:00     17
# 124  2022-01-16 03:04:00      7
#
# [125 rows x 2 columns]

# %%
filename =  "count_all.csv"
cnt.to_csv(filename, encoding = 'utf-8-sig')

# %%
path = "/Users/iomacbookair2/Documents/lab/DEIM2023/experiment1/annkw/220116_annkw_exp1.csv"
df = pd.read_csv((path))
df['created_at'] = pd.to_datetime(df['created_at'])
df.sort_values(by='created_at', ascending=True, inplace=True)
df = df.reset_index(drop=True)
df
# Out:
#               created_at                                        text
# 0    2022-01-16 02:12:00  うお！！！！この時間にROSYは寝れん！！！！#annkw #SixTONESANN
# 1    2022-01-16 02:12:01                             Rosyやん！🤙 #annkw
# 2    2022-01-16 02:12:08                                 ストだ。 #annkw
# 3    2022-01-16 02:12:08                               ロージー！！ #annkw
# 4    2022-01-16 02:12:09                               『Rosy』 #annkw
# ...                  ...                                         ...
# 1949 2022-01-16 02:34:53                          山梨の方に旅行か^ ^ #annkw
# 1950 2022-01-16 02:34:53                山梨の別荘に向かって春日家 1泊2日の旅。 #annkw
# 1951 2022-01-16 02:34:54                   春日トークゾーンって、チンやれるの？ #annkw
# 1952 2022-01-16 02:34:56                     正月旅行の話(…時間大丈夫かな？)#annkw
# 1953 2022-01-16 02:34:58                               春日を感じろ！#annkw
#
# [1954 rows x 2 columns]

# %%
c_df = df.set_index('created_at').resample('T').count()
cnt = pd.DataFrame(
    {'created_at': c_df.index.strftime('%Y-%m-%d %H:%M:%S'), 'tweet': c_df['text'].values})
cnt
# Out:
#              created_at  tweet
# 0   2022-01-16 02:12:00     45
# 1   2022-01-16 02:13:00    100
# 2   2022-01-16 02:14:00    102
# 3   2022-01-16 02:15:00     54
# 4   2022-01-16 02:16:00     34
# 5   2022-01-16 02:17:00     37
# 6   2022-01-16 02:18:00     40
# 7   2022-01-16 02:19:00     50
# 8   2022-01-16 02:20:00     82
# 9   2022-01-16 02:21:00     64
# 10  2022-01-16 02:22:00     74
# 11  2022-01-16 02:23:00     74
# 12  2022-01-16 02:24:00     84
# 13  2022-01-16 02:25:00     60
# 14  2022-01-16 02:26:00     44
# 15  2022-01-16 02:27:00    100
# 16  2022-01-16 02:28:00    188
# 17  2022-01-16 02:29:00    232
# 18  2022-01-16 02:30:00    161
# 19  2022-01-16 02:31:00    120
# 20  2022-01-16 02:32:00     96
# 21  2022-01-16 02:33:00     42
# 22  2022-01-16 02:34:00     71

# %%
filename = "count_exp1.csv"
cnt.to_csv(filename, encoding='utf-8-sig')
