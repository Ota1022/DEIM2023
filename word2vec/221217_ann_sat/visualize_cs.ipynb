# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import datetime as dt
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import ticker
import matplotlib.dates as mdates
from matplotlib.dates import date2num
from matplotlib.dates import DateFormatter
import seaborn as sns
import imageio
sns.set()

# %%
# path_cs = "/Users/iomacbookair2/Documents/lab/DEIM2023/word2vec/221217_ann_sat/cosine_similarity_w2v_221217_ann_sat.csv"
path_cs = "/Users/labimac/Documents/lab/DEIM2023/word2vec/221217_ann_sat/cosine_similarity_w2v_221217_ann_sat.csv"
df_cs = pd.read_csv((path_cs))
df_cs = df_cs.drop("texts_by_minute", axis=1)

# path_count = "/Users/iomacbookair2/Documents/lab/DEIM2023/count/count_221217_ann_sat.csv"
path_count = "/Users/labimac/Documents/lab/DEIM2023/count/count_221217_ann_sat.csv"
df_count = pd.read_csv((path_count))
df_cs["count"] = df_count["counts"]
df = df_cs
start_time = df['created_at'].min()
start_time = datetime.strptime(start_time, '%Y-%m-%d %H:%M:%S')
df['created_at'] = df['created_at'].apply(lambda x: (
    datetime.strptime(x, '%Y-%m-%d %H:%M:%S') - start_time).total_seconds() / 60)
df['created_at'] = df['created_at'].apply(lambda x: round(x))
# df['moving_average_tweet'] = df['count'].rolling(
#     window=3, min_periods=1).mean()
# df['moving_average_score'] = df['standard_deviation'].rolling(
#     window=3, min_periods=1).mean()
# df['devide'] = df['moving_average_score'] / df['moving_average_tweet']
# df.to_csv('cs_count_221217_ann_sat.csv', index=False)
df
# Out:
#      created_at    median   average    size     width  standard_deviation  \
# 0             0  1.000000  0.592690  181503  1.000000            0.484233
# 1             1  0.837228  0.324429   40755  0.837228            0.425849
# 2             2  0.444468  0.245035   12561  0.444468            0.337972
# 3             3  0.558588  0.324805    4753  0.558588            0.299909
# 4             4  0.558502  0.328890    5565  0.558502            0.281474
# ..          ...       ...       ...     ...       ...                 ...
# 120         120  0.726675  0.500179    2278  0.445026            0.289349
# 121         121  0.801375  0.492947     435  0.801375            0.374608
# 122         122  0.741721  0.500327     210  0.466419            0.301334
# 123         123  0.730090  0.561285      45  0.299582            0.204136
# 124         124  0.661766  0.507260      45  0.306296            0.198527
#
#      count
# 0      603
# 1      286
# 2      159
# 3       98
# 4      106
# ..     ...
# 120     68
# 121     30
# 122     21
# 123     10
# 124     10
#
# [125 rows x 7 columns]

# %%
window_sizes = [1]

# %%
for window in window_sizes:
    df['moving_average_tweet'] = df['count'].rolling(
        window=window, min_periods=1).mean()
    df['moving_average_score'] = df['standard_deviation'].rolling(
        window=window, min_periods=1).mean()
    fig, ax = plt.subplots(figsize=(10, 3))
    # ax.set_title("Similarity Scores and Tweet Counts of ann221218, window size: {}".format(window))
    ax.set_title("Tweet and Similarity Score of ann221218", fontsize=15)
    indices = range(0, len(df), 10)
    plt.xticks(indices, df["created_at"][indices], fontsize=15)
    ax.set_xlim(-0.5, 124.5)
    ax.set_xlabel("Minutes", fontsize=15)
    ax.set_ylabel("Tweet", fontsize=15)
    ax.bar(df["created_at"], df["moving_average_tweet"],
           color="#70d6ff", label="Tweet")
    ax2 = ax.twinx()
    ax2.set_ylim(0.5, -0.033)
    ax2.set_ylabel("Similarity", fontsize=15)
    ax2.plot(df["created_at"], df["moving_average_score"], color="red",
             label="Similarity")
    ax.legend(loc="upper right", bbox_to_anchor=(0.14, 1))
    ax2.legend(loc="upper right", bbox_to_anchor=(0.166, 0.87))
    plt.tight_layout()
    plt.savefig('animation_{}.png'.format(window))

png_files = ['animation_{}.png'.format(window) for window in window_sizes]
imageio.mimsave('animation.gif', [imageio.imread(png)
                for png in png_files], duration=0.5)
# Out:
# /var/folders/6z/_4s2jb6j5lg58zt24l9_xk440000gn/T/ipykernel_36037/1995487824.py:27: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   imageio.mimsave('animation.gif', [imageio.imread(png)

# %%
for window in window_sizes:
    df['moving_average_tweet'] = df['count'].rolling(
        window=window, min_periods=1).mean()
    df['moving_average_score'] = df['standard_deviation'].rolling(
        window=window, min_periods=1).mean()
    df['devide'] = df['moving_average_score'] / df['moving_average_tweet']
    fig, ax = plt.subplots(figsize=(10, 3))
    # ax.set_title("Similarity Score / Tweet of ann221218, window size: {}".format(window))
    ax.set_title("Similarity Score / Tweet of ann221218", fontsize=15)
    indices = range(0, len(df), 10)
    plt.xticks(indices, df["created_at"][indices], fontsize=15)
    ax.set_xlim(-0.5, 124.5)
    ax.set_ylim(0.13, -0.025)
    ax.plot(df["created_at"], df["devide"], color="red")
    ax.legend(loc="upper right", bbox_to_anchor=(1, 0.25))
    ax.set_xlabel("Time", fontsize=15)
    ax.set_ylabel("Similarity / Tweet", fontsize=15)
    plt.tight_layout()
    plt.savefig('animation_devide_{}.png'.format(window))

png_files = ['animation_devide_{}.png'.format(
    window) for window in window_sizes]
imageio.mimsave('animation_devide.gif', [imageio.imread(png)
                for png in png_files], duration=0.5)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# /var/folders/6z/_4s2jb6j5lg58zt24l9_xk440000gn/T/ipykernel_36037/1391488801.py:23: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   imageio.mimsave('animation_devide.gif', [imageio.imread(png)
