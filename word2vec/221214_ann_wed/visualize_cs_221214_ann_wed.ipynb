# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import datetime as dt
from datetime import datetime as dtdt
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import ticker
import matplotlib.dates as mdates
from matplotlib.dates import date2num
from matplotlib.dates import DateFormatter
import seaborn as sns
sns.set()

# %%
# path_cs = "/Users/iomacbookair2/Documents/lab/DEIM2023/sentense_similarity/cosine_similarity_221214_ann_wed.csv"
path_cs = "/Users/labimac/Documents/lab/DEIM2023/sentense_similarity/221214_ann_wed/cosine_similarity_w2v_221214_ann_wed.csv"
df_cs = pd.read_csv((path_cs))
df_cs = df_cs.drop("texts_by_minute", axis=1)

# path_count = "/Users/iomacbookair2/Documents/lab/DEIM2023/count/count_221214_ann_wed.csv"
path_count = "/Users/labimac/Documents/lab/DEIM2023/count/count_221214_ann_wed.csv"
df_count = pd.read_csv((path_count))
df_cs["count"] = df_count["counts"]
df = df_cs
df
# df.to_csv('cs_count_221214_ann_wed.csv', index=False)
# Out:
#               created_at    median   average    size     width  variance  \
# 0    2022-12-15 01:00:00  1.000000  0.887551  222778  0.000000  0.099320
# 1    2022-12-15 01:01:00  1.000000  0.476690   20706  1.000000  0.223955
# 2    2022-12-15 01:02:00  0.671274  0.354409   14535  0.671274  0.135168
# 3    2022-12-15 01:03:00  0.597266  0.336397   12720  0.597266  0.093618
# 4    2022-12-15 01:04:00  0.603983  0.354589   12246  0.603983  0.091640
# ..                   ...       ...       ...     ...       ...       ...
# 120  2022-12-15 03:00:00  0.243878  0.160540   12720  0.243878  0.082987
# 121  2022-12-15 03:01:00  0.510457  0.225809    3003  0.510457  0.098333
# 122  2022-12-15 03:02:00  0.713293  0.316734     465  0.713293  0.125263
# 123  2022-12-15 03:03:00  0.749243  0.522638      36  0.346227  0.092794
# 124  2022-12-15 03:04:00  0.452340  0.391023       3  0.175483  0.026115
#
#      count
# 0      668
# 1      204
# 2      171
# 3      160
# 4      157
# ..     ...
# 120    160
# 121     78
# 122     31
# 123      9
# 124      3
#
# [125 rows x 7 columns]

# %%
# Create a figure and an Axes object
fig, ax = plt.subplots(figsize=(25, 10))

ax.set_title("Similarity Scores and Tweet Counts of 221214_ann_wed")

ax.set_xlabel("Time", fontsize=20)
# Set the x-axis labels and rotate them by 90 degrees
ax.set_xticklabels(df["created_at"], rotation=90)
ax.set_xlim(-0.5, 124.5)  # グラフの横幅と全体の端を揃える

# Set the y-axis label for the count data
ax.set_ylabel("Tweet", fontsize=20)

# Plot the count data as partially transparent vertical bars
ax.bar(df["created_at"], df["count"], color="#70d6ff", label="Count of tweets")

# Create a twin Axes object for the count data
ax2 = ax.twinx()

# Set the y-axis labels
ax2.set_ylabel("Similarity", fontsize=20)

# Plot the average similarity data
ax2.plot(df["created_at"], df["variance"],
         color="red", label="Variance of sentence similarities")

# # Plot the average similarity data
# ax2.plot(df["created_at"], df["similarity[5]"],
#          color="blue", label="Average")

# Plot the average similarity data
# ax2.plot(df["created_at"], df["similarity[4]"],
#          color="red", label="100% quantile", linestyle="dashdot")

# Plot the average similarity data
# ax2.plot(df["created_at"], df["median"],
#          color="limegreen", label="Median")

# Plot the average similarity data
# ax2.plot(df["created_at"], df["similarity[1]"],
#          color="dodgerblue", label="25% quantile")

# Plot the average similarity data
# ax2.plot(df["created_at"], df["similarity[0]"],
#          color="blue", label="0% quantile", linestyle="dashdot")

# Adjust the position of the legend
ax.legend(loc="upper right", bbox_to_anchor=(1, 1))
ax2.legend(loc="upper right", bbox_to_anchor=(1, 0.95))

# Show the plot
plt.show()
# Out:
# /var/folders/6z/_4s2jb6j5lg58zt24l9_xk440000gn/T/ipykernel_77899/2584922626.py:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(df["created_at"], rotation=90)
