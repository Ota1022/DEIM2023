# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import datetime as dt
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import ticker
import matplotlib.dates as mdates
from matplotlib.dates import date2num
from matplotlib.dates import DateFormatter
import seaborn as sns
import imageio
sns.set()

# %%
path_cs = "/Users/iomacbookair2/Documents/lab/DEIM2023/word2vec/221216_ann_fri/cosine_similarity_w2v_221216_ann_fri.csv"
# path_cs = "/Users/labimac/Documents/lab/DEIM2023/sentense_similarity/221216_ann_fri/cosine_similarity_w2v_221216_ann_fri.csv"
df_cs = pd.read_csv((path_cs))
df_cs = df_cs.drop("texts_by_minute", axis=1)

path_count = "/Users/iomacbookair2/Documents/lab/DEIM2023/count/count_221216_ann_fri.csv"
# path_count = "/Users/labimac/Documents/lab/DEIM2023/count/count_221216_ann_fri.csv"
df_count = pd.read_csv((path_count))
df_cs["count"] = df_count["counts"]
df = df_cs
start_time = df['created_at'].min()
start_time = datetime.strptime(start_time, '%Y-%m-%d %H:%M:%S')
df['created_at'] = df['created_at'].apply(lambda x: (
    datetime.strptime(x, '%Y-%m-%d %H:%M:%S') - start_time).total_seconds() / 60)
df['created_at'] = df['created_at'].apply(lambda x: round(x))
# df['moving_average_tweet'] = df['count'].rolling(
#     window=3, min_periods=1).mean()
# df['moving_average_score'] = df['variance'].rolling(
#     window=3, min_periods=1).mean()
# df['devide'] = df['moving_average_score'] / df['moving_average_tweet']
# df.to_csv('cs_count_221216_ann_fri.csv', index=False)
df
# Out:
#      created_at    median   average   size     width  variance  count
# 0             0  1.000000  0.867152  20100  0.000000  0.114342    201
# 1             1  1.000000  0.562441   1485  1.000000  0.230570     55
# 2             2  0.494496  0.276390    630  0.494496  0.134208     36
# 3             3  0.567447  0.326528    528  0.567447  0.100642     33
# 4             4  0.548706  0.313005    210  0.548706  0.085243     21
# ..          ...       ...       ...    ...       ...       ...    ...
# 119         119  0.746862  0.563344    946  0.388081  0.062019     44
# 120         120  0.742405  0.515697     78  0.742405  0.113640     13
# 121         121  0.770879  0.674326     36  0.192850  0.022305      9
# 122         122  0.645642  0.645642      1  0.000000  0.000000      2
# 123         123  0.800835  0.784436      3  0.043503  0.001491      3
#
# [124 rows x 7 columns]

# %%
window_sizes = [1, 3, 5, 7, 10]

# %%
for window in window_sizes:
    df['moving_average_tweet'] = df['count'].rolling(
        window=window, min_periods=1).mean()
    df['moving_average_score'] = df['variance'].rolling(
        window=window, min_periods=1).mean()
    fig, ax = plt.subplots(figsize=(10, 3))
    ax.set_title("Similarity Scores and Tweet Counts of 221216_ann_fri, window size: {}".format(window))
    ax.set_xlabel("Time", fontsize=15)
    indices = range(0, len(df), 10)
    plt.xticks(indices, df["created_at"][indices], fontsize=15)
    ax.set_xlim(-0.5, 124.5)
    ax.set_ylabel("Tweet", fontsize=15)
    ax.bar(df["created_at"], df["moving_average_tweet"],
           color="#70d6ff", label="Moving average of tweets")
    ax2 = ax.twinx()
    ax2.set_ylim(0, 0.3)
    ax2.set_ylabel("Similarity", fontsize=15)
    ax2.plot(df["created_at"], df["moving_average_score"], color="red",
             label="Moving average of sentence similarities")
    ax.legend(loc="upper right", bbox_to_anchor=(1, 1))
    ax2.legend(loc="upper right", bbox_to_anchor=(1, 0.88))
    plt.savefig('animation_{}.png'.format(window))

png_files = ['animation_{}.png'.format(window) for window in window_sizes]
imageio.mimsave('animation.gif', [imageio.imread(png)
                for png in png_files], duration=0.5)
# Out:
# /var/folders/6j/lgj8d7m91v7d19xc2r4wgwlr0000gn/T/ipykernel_57726/997091257.py:25: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   imageio.mimsave('animation.gif', [imageio.imread(png)

# %%
for window in window_sizes:
    df['moving_average_tweet'] = df['count'].rolling(
        window=window, min_periods=1).mean()
    df['moving_average_score'] = df['variance'].rolling(
        window=window, min_periods=1).mean()
    df['devide'] = df['moving_average_score'] / df['moving_average_tweet']
    fig, ax = plt.subplots(figsize=(10, 3))
    ax.set_title("Tweet Counts / Similarity Scores of 221216_ann_fri, window size: {}".format(window))
    ax.set_xlabel("Time", fontsize=15)
    indices = range(0, len(df), 10)
    plt.xticks(indices, df["created_at"][indices], fontsize=15)
    ax.set_xlim(-0.5, 124.5)
    ax.set_ylim(0, 0.05)
    ax.set_ylabel("Tweet / Similarity", fontsize=15)
    ax.plot(df["created_at"], df["devide"], color="red", label="Moving average of tweet counts / sentence similarities")
    ax.legend(loc="upper right", bbox_to_anchor=(1, 1))
    plt.savefig('animation_devide_{}.png'.format(window))

png_files = ['animation_devide_{}.png'.format(
    window) for window in window_sizes]
imageio.mimsave('animation_devide.gif', [imageio.imread(png)
                for png in png_files], duration=0.5)
# Out:
# /var/folders/6j/lgj8d7m91v7d19xc2r4wgwlr0000gn/T/ipykernel_57726/277944553.py:21: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   imageio.mimsave('animation_devide.gif', [imageio.imread(png)
