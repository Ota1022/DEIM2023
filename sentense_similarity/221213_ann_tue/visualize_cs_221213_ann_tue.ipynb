# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import datetime as dt
from datetime import datetime as dtdt
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import ticker
import matplotlib.dates as mdates
from matplotlib.dates import date2num
from matplotlib.dates import DateFormatter
import seaborn as sns
sns.set()

# %%
# path_cs = "/Users/iomacbookair2/Documents/lab/DEIM2023/sentense_similarity/cosine_similarity_221213_ann_tue.csv"
path_cs = "/Users/labimac/Documents/lab/DEIM2023/sentense_similarity/221213_ann_tue/cosine_similarity_w2v_221213_ann_tue.csv"
df_cs = pd.read_csv((path_cs))
df_cs = df_cs.drop("texts_by_minute", axis=1)

# path_count = "/Users/iomacbookair2/Documents/lab/DEIM2023/count/count_221213_ann_tue.csv"
path_count = "/Users/labimac/Documents/lab/DEIM2023/count/count_221213_ann_tue.csv"
df_count = pd.read_csv((path_count))
df_cs["count"] = df_count["counts"]
df = df_cs
df
# df.to_csv('cs_count_221213_ann_tue.csv', index=False)
# Out:
#               created_at    median   average   size     width  variance  count
# 0    2022-12-14 01:00:00  1.000000  0.667899  20301  1.000000  0.217316    202
# 1    2022-12-14 01:01:00  1.000000  0.341126   6903  1.000000  0.195341    118
# 2    2022-12-14 01:02:00  0.444460  0.232784   1891  0.444460  0.083605     62
# 3    2022-12-14 01:03:00  0.575540  0.344060   1891  0.575540  0.080646     62
# 4    2022-12-14 01:04:00  0.619481  0.373039   2278  0.619481  0.085895     68
# ..                   ...       ...       ...    ...       ...       ...    ...
# 120  2022-12-14 03:00:00  0.779716  0.524603    990  0.541426  0.101333     45
# 121  2022-12-14 03:01:00  0.802628  0.544734    351  0.802628  0.116576     27
# 122  2022-12-14 03:02:00  0.833680  0.762635    120  0.129990  0.011800     16
# 123  2022-12-14 03:03:00  0.868218  0.637365     66  0.326630  0.096646     12
# 124  2022-12-14 03:04:00  0.795010  0.745553      3  0.092997  0.005836      3
#
# [125 rows x 7 columns]

# %%
# Create a figure and an Axes object
fig, ax = plt.subplots(figsize=(25, 10))

ax.set_title("Similarity Scores and Tweet Counts of 221213_ann_tue")

ax.set_xlabel("Time", fontsize=20)
# Set the x-axis labels and rotate them by 90 degrees
ax.set_xticklabels(df["created_at"], rotation=90)
ax.set_xlim(-0.5, 124.5)  # グラフの横幅と全体の端を揃える

# Set the y-axis label for the count data
ax.set_ylabel("Tweet", fontsize=20)

# Plot the count data as partially transparent vertical bars
ax.bar(df["created_at"], df["count"], color="#70d6ff", label="Count of tweets")

# Create a twin Axes object for the count data
ax2 = ax.twinx()

# Set the y-axis labels
ax2.set_ylabel("Similarity", fontsize=20)

# Plot the average similarity data
ax2.plot(df["created_at"], df["variance"],
         color="red", label="Variance of sentence similarities")

# # Plot the average similarity data
# ax2.plot(df["created_at"], df["similarity[5]"],
#          color="blue", label="Average")

# Plot the average similarity data
# ax2.plot(df["created_at"], df["similarity[4]"],
#          color="red", label="100% quantile", linestyle="dashdot")

# Plot the average similarity data
# ax2.plot(df["created_at"], df["median"],
#          color="limegreen", label="Median")

# Plot the average similarity data
# ax2.plot(df["created_at"], df["similarity[1]"],
#          color="dodgerblue", label="25% quantile")

# Plot the average similarity data
# ax2.plot(df["created_at"], df["similarity[0]"],
#          color="blue", label="0% quantile", linestyle="dashdot")

# Adjust the position of the legend
ax.legend(loc="upper right", bbox_to_anchor=(1, 1))
ax2.legend(loc="upper right", bbox_to_anchor=(1, 0.95))

# Show the plot
plt.show()
# Out:
# /var/folders/6z/_4s2jb6j5lg58zt24l9_xk440000gn/T/ipykernel_76842/857171103.py:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(df["created_at"], rotation=90)
