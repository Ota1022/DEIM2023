# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import datetime as dt
from datetime import datetime as dtdt
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import ticker
import matplotlib.dates as mdates
from matplotlib.dates import date2num
from matplotlib.dates import DateFormatter
import seaborn as sns
sns.set()

# %%
# path_cs = "/Users/iomacbookair2/Documents/lab/DEIM2023/sentense_similarity/cosine_similarity_221216_ann_fri.csv"
path_cs = "/Users/labimac/Documents/lab/DEIM2023/sentense_similarity/221216_ann_fri/cosine_similarity_w2v_221216_ann_fri.csv"
df_cs = pd.read_csv((path_cs))
df_cs = df_cs.drop("texts_by_minute", axis=1)

# path_count = "/Users/iomacbookair2/Documents/lab/DEIM2023/count/count_221216_ann_fri.csv"
path_count = "/Users/labimac/Documents/lab/DEIM2023/count/count_221216_ann_fri.csv"
df_count = pd.read_csv((path_count))
df_cs["count"] = df_count["counts"]
df = df_cs
df
# df.to_csv('cs_count_221216_ann_fri.csv', index=False)
# Out:
#               created_at    median   average   size     width  variance  count
# 0    2022-12-17 01:00:00  1.000000  0.867152  20100  0.000000  0.114342    201
# 1    2022-12-17 01:01:00  1.000000  0.562441   1485  1.000000  0.230570     55
# 2    2022-12-17 01:02:00  0.494496  0.276390    630  0.494496  0.134208     36
# 3    2022-12-17 01:03:00  0.567447  0.326528    528  0.567447  0.100642     33
# 4    2022-12-17 01:04:00  0.548706  0.313005    210  0.548706  0.085243     21
# ..                   ...       ...       ...    ...       ...       ...    ...
# 119  2022-12-17 02:59:00  0.746862  0.563344    946  0.388081  0.062019     44
# 120  2022-12-17 03:00:00  0.742405  0.515697     78  0.742405  0.113640     13
# 121  2022-12-17 03:01:00  0.770879  0.674326     36  0.192850  0.022305      9
# 122  2022-12-17 03:02:00  0.645642  0.645642      1  0.000000  0.000000      2
# 123  2022-12-17 03:03:00  0.800835  0.784436      3  0.043503  0.001491      3
#
# [124 rows x 7 columns]

# %%
# Create a figure and an Axes object
fig, ax = plt.subplots(figsize=(25, 10))

ax.set_title("Similarity Scores and Tweet Counts of 221216_ann_fri")

ax.set_xlabel("Time", fontsize=20)
# Set the x-axis labels and rotate them by 90 degrees
ax.set_xticklabels(df["created_at"], rotation=90)
ax.set_xlim(-0.5, 124.5)  # グラフの横幅と全体の端を揃える

# Set the y-axis label for the count data
ax.set_ylabel("Tweet", fontsize=20)

# Plot the count data as partially transparent vertical bars
ax.bar(df["created_at"], df["count"], color="#70d6ff", label="Count of tweets")

# Create a twin Axes object for the count data
ax2 = ax.twinx()

# Set the y-axis labels
ax2.set_ylabel("Similarity", fontsize=20)

# Plot the average similarity data
ax2.plot(df["created_at"], df["variance"],
         color="red", label="Variance of sentence similarities")

# # Plot the average similarity data
# ax2.plot(df["created_at"], df["similarity[5]"],
#          color="blue", label="Average")

# Plot the average similarity data
# ax2.plot(df["created_at"], df["similarity[4]"],
#          color="red", label="100% quantile", linestyle="dashdot")

# Plot the average similarity data
# ax2.plot(df["created_at"], df["median"],
#          color="limegreen", label="Median")

# Plot the average similarity data
# ax2.plot(df["created_at"], df["similarity[1]"],
#          color="dodgerblue", label="25% quantile")

# Plot the average similarity data
# ax2.plot(df["created_at"], df["similarity[0]"],
#          color="blue", label="0% quantile", linestyle="dashdot")

# Adjust the position of the legend
ax.legend(loc="upper right", bbox_to_anchor=(1, 1))
ax2.legend(loc="upper right", bbox_to_anchor=(1, 0.95))

# Show the plot
plt.show()
# Out:
# /var/folders/6z/_4s2jb6j5lg58zt24l9_xk440000gn/T/ipykernel_78368/666982902.py:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(df["created_at"], rotation=90)
