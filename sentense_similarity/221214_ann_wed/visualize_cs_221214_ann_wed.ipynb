# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import datetime as dt
from datetime import datetime as dtdt
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import ticker
import matplotlib.dates as mdates
from matplotlib.dates import date2num
from matplotlib.dates import DateFormatter
import seaborn as sns
sns.set()

# %%
path_cs = "/Users/iomacbookair2/Documents/lab/DEIM2023/sentense_similarity/221214_ann_wed/cosine_similarity_221214_ann_wed.csv"
df_cs = pd.read_csv((path_cs))
df_cs = df_cs.drop("texts_by_minute", axis=1)

path_count = "/Users/iomacbookair2/Documents/lab/DEIM2023/count/count_221214_ann_wed.csv"
df_count = pd.read_csv((path_count))
df_cs["count"] = df_count["counts"]
df = df_cs
df
# df.to_csv('cs_count_221212_ann_mon.csv', index=False)
# Out:
#               created_at  average_similarity  count
# 0    2022-12-15 01:00:00            0.977954    668
# 1    2022-12-15 01:01:00            0.864120    204
# 2    2022-12-15 01:02:00            0.738300    171
# 3    2022-12-15 01:03:00            0.669687    160
# 4    2022-12-15 01:04:00            0.726158    157
# ..                   ...                 ...    ...
# 120  2022-12-15 03:00:00            0.814245    160
# 121  2022-12-15 03:01:00            0.742052     78
# 122  2022-12-15 03:02:00            0.784267     31
# 123  2022-12-15 03:03:00            0.683805      9
# 124  2022-12-15 03:04:00            0.834853      3
#
# [125 rows x 3 columns]

# %%
# Create a figure and an Axes object
fig, ax = plt.subplots(figsize=(25, 10))

ax.set_title("Average Similarity Scores and Tweet Counts of 221214_ann_wed")

ax.set_xlabel("Time", fontsize=20)
# Set the x-axis labels and rotate them by 90 degrees
ax.set_xticklabels(df["created_at"], rotation=90)
ax.set_xlim(-0.5, 124.5) # グラフの横幅と全体の端を揃える

# Set the y-axis label for the count data
ax.set_ylabel("Count", fontsize=20)

# Plot the count data as partially transparent vertical bars
ax.bar(df["created_at"], df["count"], color="#70d6ff", label="Count")

# Create a twin Axes object for the count data
ax2 = ax.twinx()

# Set the y-axis labels
ax2.set_ylabel("Average Similarity", fontsize=20)

# Plot the average similarity data
ax2.plot(df["created_at"], df["average_similarity"], color="red", label="Average Similarity")

# Adjust the position of the legend
ax.legend(loc="upper right", bbox_to_anchor=(1,0.98))
ax2.legend(loc="upper right", bbox_to_anchor=(1,0.94))

# Show the plot
plt.show()
# Out:
# /var/folders/6j/lgj8d7m91v7d19xc2r4wgwlr0000gn/T/ipykernel_4629/3911193904.py:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(df["created_at"], rotation=90)
