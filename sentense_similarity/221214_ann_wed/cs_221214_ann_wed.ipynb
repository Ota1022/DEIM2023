# %% [markdown]
# - csv と transformers ライブラリがインポートされ、transformers ライブラリから BertTokenizer と BertModel クラスを使用して BERT トークナイザとモデルがロードされています。
# - 2212.csv ファイルが読み取りモードで開かれ、ファイルを読み取るために CSV リーダー オブジェクトが作成されます。
# - ヘッダ行は next 関数を用いてスキップされます。
# - CSV ファイルの行を繰り返し処理するために、for ループが使用されます。各行について、日付、文、ユーザ名の値が抽出される。
# - 文は、BERT トークナイザーを使用して BERT 入力として符号化され、文の BERT 埋め込みは、BERT モデルを使用して計算されます。
# -  文の BERT 埋め込みは、モデル出力から抽出される。
# - 文の埋め込みと参照埋め込みとの間のコサイン類似度は、PyTorchのnnモジュールのCosineSimilarityクラスを使って計算される。
# - 日付、文、ユーザ名、類似度の値が出力される。

# %%
import pandas as pd
import torch
from transformers import BertJapaneseTokenizer, BertModel
import re

MODEL_NAME = 'cl-tohoku/bert-base-japanese-whole-word-masking'
tokenizer = BertJapaneseTokenizer.from_pretrained(MODEL_NAME)
model = BertModel.from_pretrained(MODEL_NAME)
# Out:
# Some weights of the model checkpoint at cl-tohoku/bert-base-japanese-whole-word-masking were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
path = "/Users/iomacbookair2/Documents/lab/DEIM2023/tweet_csv/221214_ann_wed.csv"
df = pd.read_csv((path))
df.sort_values(by = 'created_at', ascending = True, inplace = True)
df = df.reset_index(drop=True)
df['created_at'] = pd.to_datetime(df['created_at'])
df = df.drop("author_id", axis=1)
df = df.drop("username", axis=1)

df
# df.to_csv("sorted.csv", index=False)
# Out:
#                created_at                                               text
# 0     2022-12-15 01:00:00                                          #乃木坂46ANN
# 1     2022-12-15 01:00:00                                          #乃木坂46ANN
# 2     2022-12-15 01:00:00                                          #乃木坂46ANN
# 3     2022-12-15 01:00:00                                          #乃木坂46ANN
# 4     2022-12-15 01:00:00                                          #乃木坂46ANN
# ...                   ...                                                ...
# 13960 2022-12-15 03:03:55  おごりのカッコいい払い方って難しいけど、だからこそかっこいいのかな？ ちゃんとスポーツ観戦し...
# 13961 2022-12-15 03:03:56                                 お疲れ様でした  #乃木坂46ANN
# 13962 2022-12-15 03:04:11  しおりさん、スタッフさんオツカレサマデシタ！！ 久々の1人喋りスポーツの話満載でしたが色んな...
# 13963 2022-12-15 03:04:13  12/14㈬#あちこちオードリー #乃木坂46ANN #SPYのボスの正体は佐久間宣行 #f...
# 13964 2022-12-15 03:04:23  なんだ、この『野球太郎』宣伝ラジオｗ 　#乃木坂46ANN　ポチっていただいた方もありがとう...
#
# [13965 rows x 2 columns]

# %%
def remove_urls_and_hashtags(text):
    # Remove URLs
    text = re.sub(r'https?://\S+', '', text)
    # Remove words starting with "#"
    text = re.sub(r'#\S+', '', text)
    text = re.sub(r'＃\S+', '', text)
    return text


df['text'] = df['text'].apply(remove_urls_and_hashtags)
df
# df.to_csv('filtered.csv', index=False)
# Out:
#                created_at                                               text
# 0     2022-12-15 01:00:00
# 1     2022-12-15 01:00:00
# 2     2022-12-15 01:00:00
# 3     2022-12-15 01:00:00
# 4     2022-12-15 01:00:00
# ...                   ...                                                ...
# 13960 2022-12-15 03:03:55  おごりのカッコいい払い方って難しいけど、だからこそかっこいいのかな？ ちゃんとスポーツ観戦し...
# 13961 2022-12-15 03:03:56                                          お疲れ様でした
# 13962 2022-12-15 03:04:11  しおりさん、スタッフさんオツカレサマデシタ！！ 久々の1人喋りスポーツの話満載でしたが色んな...
# 13963 2022-12-15 03:04:13  12/14㈬     続き 3時~元テレ東P[ 📹無料映像配信も【HAKUNA Live】👉...
# 13964 2022-12-15 03:04:23  なんだ、この『野球太郎』宣伝ラジオｗ 　　ポチっていただいた方もありがとうございました！　で...
#
# [13965 rows x 2 columns]

# %%
groups = df.groupby(pd.Grouper(key='created_at', freq='min'))
df_texts_by_minute = pd.DataFrame({
    "texts_by_minute": groups.apply(lambda x: x["text"].tolist())
})
df_texts_by_minute = df_texts_by_minute.reset_index()
df_texts_by_minute
# df_texts_by_minute.to_csv("texts_by_minute.csv", index=False)
# Out:
#              created_at                                    texts_by_minute
# 0   2022-12-15 01:00:00  [, , , , , , , , , , , , , さあ、今夜も お願いします！ お願いし...
# 1   2022-12-15 01:01:00  [  ,   遅延, , , , , , , , こんなんなんぼあってもいいですからね  ,...
# 2   2022-12-15 01:02:00  [, 森高千里さんから可愛いをいただいた久保ちゃん(笑) 可愛いなんてなんぼ言われてもいいよ...
# 3   2022-12-15 01:03:00  [やかましいわ , 久保ちゃん、それ聞いちゃおしまいよ ,  頑張っちゃってください, クリ...
# 4   2022-12-15 01:04:00  [あの森高千里さんから「かわいい」頂きましたｗ  ,  クリスマスツリーとシュトーレンを買う...
# ..                  ...                                                ...
# 120 2022-12-15 03:00:00  [今週もお疲れ様でした！ かっこつけようとして、失敗してしまったのがくぼちゃんらしいです笑 ...
# 121 2022-12-15 03:01:00  [『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソ...
# 122 2022-12-15 03:02:00  [またねー  , しおりんお疲れ様でした〜！ 来週も絶対聴く！👂 またね〜(´▽`)ﾉ   ...
# 123 2022-12-15 03:03:00  [敗者復活でやるような場所じゃない , 久保ちゃんお疲れ様でした🎵 ソロはひさびさでしたね ...
# 124 2022-12-15 03:04:00  [しおりさん、スタッフさんオツカレサマデシタ！！ 久々の1人喋りスポーツの話満載でしたが色ん...
#
# [125 rows x 2 columns]

# %%
def sentence_to_vector(model, tokenizer, sentence):
    tokens = tokenizer(sentence, add_special_tokens=True)["input_ids"]
    input = torch.tensor(tokens).unsqueeze(0)
    with torch.no_grad():
        outputs = model(input, output_hidden_states=True)
        last_hidden_state = outputs[0][:, 0, :]
        averaged_hidden_state = last_hidden_state.mean(dim=0).unsqueeze(0)
    return averaged_hidden_state


def calc_similarity(sentence1, sentence2):
    print("{}\n{}".format(sentence1, sentence2))

    sentence_vector1 = sentence_to_vector(model, tokenizer, sentence1)
    sentence_vector2 = sentence_to_vector(model, tokenizer, sentence2)

    # Reshape the tensors to 1D
    sentence_vector1 = sentence_vector1.reshape(-1)
    sentence_vector2 = sentence_vector2.reshape(-1)

    similarity = float(torch.nn.functional.cosine_similarity(
        sentence_vector1, sentence_vector2, dim=0).detach().numpy().copy())
    print("Similarity:", similarity)

    return similarity


def calc_average_similarity(sentences):
    similarities = []
    for i in range(1, len(sentences)):
        similarity = calc_similarity(sentences[0], sentences[i])
        similarities.append(similarity)
    average_similarity = sum(similarities) / len(similarities)
    # print("Similarities:", similarities)
    print("Average similarity:", average_similarity)

    return average_similarity

# %%
df_texts_by_minute["average_similarity"] = df_texts_by_minute["texts_by_minute"].apply(
    calc_average_similarity)
df_texts_by_minute
# Out:
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# さあ、今夜も お願いします！ お願いします！ お願いします！
# Similarity: 0.6659478545188904
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# 乃木坂46のオールナイトニッポン | ニッポン放送 | 2022/12/14/水  25:00-27:00
# Similarity: 0.7102256417274475
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# 185
# Similarity: 0.702856719493866
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# 流石にホテルの目の前だとよく聴こえるなぁ(送信所そこじゃねぇよ)
# Similarity: 0.6282414793968201
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#  のお時間です
# Similarity: 0.6185581088066101
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# スペシャルウィークのゲスト今日発表だと思うけど、絶対飛鳥ちゃんだと思う。大穴として真夏飛鳥史緒里の3人
# Similarity: 0.7325284481048584
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# 寝ます おやすみなさい
# Similarity: 0.625028133392334
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# そろそろ轍ができる頃。 年内放送もあとわずか。 また新たな第40回放送。 よろしくね。
# Similarity: 0.654457151889801
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# オールナイトニッポン | KBCラジオ
# Similarity: 0.7747803330421448
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# くぼせんせー！よろしこ！
# Similarity: 0.6746447682380676
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#  から   🚴💨
# Similarity: 0.6498121619224548
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# START→→→
# Similarity: 0.6763783097267151
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# 乃木坂46のオールナイトニッポン │ ニッポン放送
# Similarity: 0.6587218046188354
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# 定刻
# Similarity: 0.6900166869163513
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#  📻️🎶
# Similarity: 0.7170608043670654
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# しーちゃん、こんばんは！
# Similarity: 0.6381977796554565
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# くぼちゃんこんばんは
# Similarity: 0.6373602747917175
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# スタート！
# Similarity: 0.7207338809967041
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# 始まった～📻
# Similarity: 0.6474617123603821
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# 今夜もRCC
# Similarity: 0.7791013717651367
#
#  例の人が来る
# Similarity: 0.6563302278518677
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# CD渡せたんだよね
# Similarity: 0.5464315414428711
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# 寒いわね…
# Similarity: 0.5537837743759155
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# くぼしーさん〜
# Similarity: 0.6187323927879333
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# 今週もお願いしナス お願いしナス お願いしナス
# Similarity: 0.5867127776145935
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# ここからは、しおりてぇゃん♥️のステージだ！
# Similarity: 0.6578754782676697
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# 写真で見ましたよ！！！
# Similarity: 0.5870547890663147
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# 1時だァ( ᐛ )
# Similarity: 0.6888945698738098
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# 始まった笑
# Similarity: 0.690484881401062
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# 森高千里さんの生放送にFNSでコラボしたお礼に！
# Similarity: 0.6210273504257202
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# radikoだから ラグがスゴい
# Similarity: 0.6590657234191895
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# ジンジンジングルベル録画しててまだ見てない笑
# Similarity: 0.7232128977775574
#
# 森高千里の  にご挨拶してきた久保
# Similarity: 0.6889597773551941
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# 森高千里さんにお礼を言いに
# Similarity: 0.7460853457450867
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# 森高千里さんのラジオの方に、お邪魔してたそうで。  FNS歌謡祭でコラボしてましたからね。
# Similarity: 0.5742917060852051
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# 今週も始まった〜＼(^o^)／
# Similarity: 0.6216280460357666
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# 作業を切り上げつつ  をまったりと．
# Similarity: 0.6850751638412476
#
#
# Similarity: 0.9999997615814209
#
# 聴きます
# Similarity: 0.6537197828292847
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# 始まった😍🎵乃木坂46ANN
# Similarity: 0.651414155960083
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# あー披露したね
# Similarity: 0.594210147857666
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# よかったね
# Similarity: 0.585247278213501
#
# ﾄﾞﾌｯ!!(？)
# Similarity: 0.6367313265800476
#
#
# Similarity: 0.9999997615814209
#
# しーちゃん♥️鷲尾ちゃん♥️
# Similarity: 0.6667177081108093
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
# Average similarity: 0.9779544999931884
#
#   遅延
# Similarity: 0.6933743357658386
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# こんなんなんぼあってもいいですからね
# Similarity: 0.5843337774276733
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# 放送スタート！！
# Similarity: 0.6846128106117249
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# じんじんじんぐるべる←かわいい
# Similarity: 0.6735244989395142
#
#
# Similarity: 0.9999997615814209
#
# ここにはないもののシングルをお届け！ 森高千里さんから、可愛いをいただいたしーちゃん！
# Similarity: 0.6778940558433533
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# ニールナイトオッポン始まった！    📻
# Similarity: 0.6934720277786255
#
# 森高千里さんからかわいい頂いた！
# Similarity: 0.6766768097877502
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# 可愛いなんてなんぼあってもいいですからね〜
# Similarity: 0.6078546643257141
#
# 森高千里に可愛いって言われて喜ぶ久保ちゃん
# Similarity: 0.6589354872703552
#
# 森髙さんに挨拶を
# Similarity: 0.7521486282348633
#
#
# Similarity: 0.9999997615814209
#
# 森高千里さんに可愛いと言われた久保ちゃん
# Similarity: 0.6568004488945007
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#    『どんっ！  さぁ～始まりました！ ニッポン放送・乃木坂ちゃんのオールナイトニッポン！  12月14日水曜日、明けて15日の木曜日でございます～  いや～日村さん～』  『何ですか？設楽さん？』
# Similarity: 0.6903231143951416
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#   久保ちゃん、こんばんは！ 今週も3時までよろしくね〜😊
# Similarity: 0.6278744339942932
#
#
# Similarity: 0.9999997615814209
#
# 久々に久保ちゃんソロ  乃木坂46のオールナイトニッポン | ニッポン放送
# Similarity: 0.7283867597579956
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# 乃木坂46のオールナイトニッポン | ニッポン放送
# Similarity: 0.7301952838897705
#
#  MUSIC10やってる所に行ってきたのね
# Similarity: 0.5831345319747925
#
# こんばんはー！
# Similarity: 0.7027619481086731
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# 森高千里にかわいいって言われて嬉しがるしーちゃんがかわいい。
# Similarity: 0.6747420430183411
#
#
# Similarity: 0.9999997615814209
#
# 森高千里さんがツイートされていましたね！
# Similarity: 0.6334118843078613
#
# 森高千里さんから「かわいい」をいただいた久保史緒里さん
# Similarity: 0.637758195400238
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# 実はですね  からスタート
# Similarity: 0.7299386858940125
#
#
# Similarity: 0.9999997615814209
#
# 可愛かったです！！！
# Similarity: 0.5681931972503662
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# いきなり森高千里さんとの接触話👏👏
# Similarity: 0.6907434463500977
#
#
# Similarity: 0.9999997615814209
#
# 森高千里さんからかわいい頂きましたw
# Similarity: 0.6299670338630676
#
#  今週も始まった
# Similarity: 0.5815778374671936
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# あら、可愛いいただけたの！！！ 嬉しいですよね！！！そりゃ！！
# Similarity: 0.6342198848724365
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# 森高さん…！
# Similarity: 0.6458673477172852
#
#
# Similarity: 0.9999997615814209
#
# ほんとに綺麗なんだよなぁ…
# Similarity: 0.6454409956932068
#
# ヨッ‼️‼️可愛いよ‼️‼️‼️‼️‼️
# Similarity: 0.6260169744491577
#
# 森高さんから可愛いいただきました！
# Similarity: 0.5964592099189758
#
# くぼさまおばんです〜！
# Similarity: 0.6715787649154663
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#  ＆
# Similarity: 0.7849404811859131
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# 森高さんの挨拶させていただいたしおちゃん
# Similarity: 0.7032394409179688
#
#
# Similarity: 0.9999997615814209
#
# 実はですねスタート！！！
# Similarity: 0.6318953037261963
#
# 可愛いいただけたかww
# Similarity: 0.6412298083305359
#
#
# Similarity: 0.9999997615814209
#
# カワイイ頂きました
# Similarity: 0.6372529864311218
#
# ええやん！
# Similarity: 0.7100600600242615
#
# 森高千里さんから可愛いゲット！
# Similarity: 0.6308093070983887
#
#
# Similarity: 0.9999997615814209
#
# 放送前に森高千里さんとお話をしたんですね。
# Similarity: 0.5746092200279236
#
#
# Similarity: 0.9999997615814209
#
#   曲間に渡したんだ！！！
# Similarity: 0.571812629699707
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# 私がおばさんになっても〜♪
# Similarity: 0.6061944961547852
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# くぼちゃんかわいいぞー！
# Similarity: 0.6885342597961426
#
# お、さっきその写真見たぞーぃ
# Similarity: 0.6634312272071838
#
# 毎回歌ってるんかい笑笑
# Similarity: 0.648719310760498
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# これだね~
# Similarity: 0.6463539600372314
#
#
# Similarity: 0.9999997615814209
#
# 今日は島内の件についてのコメントを聞きたいのよ
# Similarity: 0.6706772446632385
#
# 可愛いです！！
# Similarity: 0.6316016316413879
#
# 森高さんから「かわいい」を頂いた久保ちゃん
# Similarity: 0.6436372995376587
#
#
# Similarity: 0.9999997615814209
#
# 森高千里さんから｢かわいい｣を頂きました笑笑
# Similarity: 0.6615989208221436
#
# 可愛いよぉ
# Similarity: 0.615985631942749
#
# 森高さんにご挨拶
# Similarity: 0.689805805683136
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# 乃木坂46のオールナイトニッポン | ニッポン放送
# Similarity: 0.7301952838897705
#
#
# Similarity: 0.9999997615814209
#
# 我々からも「可愛い」を贈呈します
# Similarity: 0.6786512732505798
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# 毎日お風呂で歌ってるww
# Similarity: 0.6494720578193665
#
# 森高千里からカワイイを頂いた久保ちゃん。
# Similarity: 0.6374935507774353
#
#
# Similarity: 0.9999997615814209
#
# 今日はラジオで拝聴中！
# Similarity: 0.6528366208076477
#
# 今の軽く歌う感じで歌のうまさが分かる凄さ。
# Similarity: 0.5919864773750305
#
#
# Similarity: 0.9999997615814209
#
# 可愛いを頂いたのね笑
# Similarity: 0.6382474303245544
#
#
# Similarity: 0.9999997615814209
#
# 森高さんに挨拶 カワイイ頂きました
# Similarity: 0.6315486431121826
#
#
# Similarity: 0.9999997615814209
#
# 今から課題っていう地獄やけど久保ちゃんのおかげでなんとかなりそう
# Similarity: 0.6490129232406616
#
#   この時か
# Similarity: 0.6633499264717102
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# オールナイトニッポン | CBCラジオ
# Similarity: 0.6477428078651428
#
# 可愛い頂きましたww
# Similarity: 0.6617146730422974
#
# おめでとうございます笑👏🏻
# Similarity: 0.6667342782020569
#
# そのツイート見ました！！！
# Similarity: 0.6532348990440369
#
# かわいいいただきました😂
# Similarity: 0.6001744270324707
#
# 行ってましたね〜
# Similarity: 0.6018558144569397
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# しおりちゃん可愛いもん💕
# Similarity: 0.6650928258895874
#
# 乃木坂46のオールナイトニッポン | ニッポン放送
# Similarity: 0.7301952838897705
#
#  かわいい頂きました笑
# Similarity: 0.657864511013031
#
# これですね。
# Similarity: 0.6241282224655151
#
# かわいいよ💦💦💦💦
# Similarity: 0.6249229311943054
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# 全然おばさんにならない森高千里
# Similarity: 0.688697099685669
#
#
# Similarity: 0.9999997615814209
#
# たしかに森高千里さんめっちゃ綺麗。
# Similarity: 0.65366530418396
#
# 乃木坂46×森高千里のコラボがFNS歌謡祭以降も続いてるなんて感涙…
# Similarity: 0.622580349445343
#
# 可愛い頂きましたww
# Similarity: 0.6617146730422974
#
#
# Similarity: 0.9999997615814209
#
# 可愛い頂きましたぁ！
# Similarity: 0.6661624908447266
#
# 森高千里、いつおばさんになるの？問題
# Similarity: 0.6953208446502686
#
# 森高千里さんから｢かわいい｣
# Similarity: 0.6385517716407776
#
# 森高さんからのかわいいは至高
# Similarity: 0.6927124261856079
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
# Average similarity: 0.8641203873850442
#
# 森高千里さんから可愛いをいただいた久保ちゃん(笑) 可愛いなんてなんぼ言われてもいいよね～嬉しいよね😁
# Similarity: 0.651220977306366
#
# "かわいい"いただきましたー！！
# Similarity: 0.6384546756744385
#
# 嗚呼生歌
# Similarity: 0.7108092904090881
#
# ご飯食べつつ聴くか。
# Similarity: 0.630661129951477
#
# 39回目の登板
# Similarity: 0.6056438088417053
#
#
# Similarity: 0.9999997615814209
#
# かわいいはナンボいただいてもいいですからね
# Similarity: 0.6177628636360168
#
# しおりちゃんがおばさんになってもめちゃくちゃ海連れて行くけどね
# Similarity: 0.5782078504562378
#
# 森高千里からの「かわいい」
# Similarity: 0.6440714001655579
#
# 今日のMUSIC10は森高さんでしたね
# Similarity: 0.5898032784461975
#
# 森高さん何曲か歌ったけどどれもすごかったね
# Similarity: 0.5950444936752319
#
# 森高千里さんの可愛いには俺らの可愛いの何万倍もの価値があるな。
# Similarity: 0.6185721158981323
#
#
# Similarity: 0.9999997615814209
#
# 可愛いをいただきました。
# Similarity: 0.6228347420692444
#
# 森高千里さんからかわいいをいただきｗ
# Similarity: 0.6670108437538147
#
#
# Similarity: 0.9999997615814209
#
#  森高さんから可愛いもらったくぼしー笑
# Similarity: 0.7064431309700012
#
# 今日も久保さんの声で癒されます。 森高千里さんの話から。
# Similarity: 0.6510553359985352
#
#
# Similarity: 0.9999997615814209
#
# 森高千里さんから可愛い頂いた久保
# Similarity: 0.570080041885376
#
#
# Similarity: 0.9999997615814209
#
# お歌きたぁぁぁぁ
# Similarity: 0.7326880097389221
#
#
# Similarity: 0.9999997615814209
#
# 可愛いいただけてよかったね！
# Similarity: 0.62240070104599
#
# 森高さんから可愛いを頂いた久保ちゃん
# Similarity: 0.6377507448196411
#
# 今週もお願いしますっ
# Similarity: 0.6414607763290405
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# 森高千里さんに可愛いいただいたのねw
# Similarity: 0.5725604891777039
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# FNS歌謡祭でコラボした森高さんとばったりですか
# Similarity: 0.6322828531265259
#
# 可愛い方からの可愛いは嬉しいね
# Similarity: 0.6506301760673523
#
# それは推してる側としても嬉しいな
# Similarity: 0.633222758769989
#
# 森高千里さんにお礼とシングルをお渡し 「可愛い」頂きました"(∩&gt;ω&lt;∩)"笑
# Similarity: 0.6820982694625854
#
# 可愛い
# Similarity: 0.6294587254524231
#
#
# Similarity: 0.9999997615814209
#
#   森高さんからのかわいいは嬉しいなw
# Similarity: 0.6595275402069092
#
# 森高さんから"可愛い"良かったね！
# Similarity: 0.589748740196228
#
# 森高千里さんから可愛いって言われたの良かったね〜
# Similarity: 0.5775533318519592
#
#
# Similarity: 0.9999997615814209
#
# 誰が見てもあなたは可愛いのよ
# Similarity: 0.5765607953071594
#
#
# Similarity: 0.9999997615814209
#
# 剛剛被森高千里さん誇了可愛w
# Similarity: 0.704253613948822
#
# 森高千里さんからかわいい頂きました！
# Similarity: 0.6570691466331482
#
# 可愛い良かったねえ🥰
# Similarity: 0.6173552870750427
#
#
# Similarity: 0.9999997615814209
#
# 歳をとっても、一緒に海に行きたいね！///
# Similarity: 0.6141760349273682
#
# 橋本環奈に似てるからね〜()
# Similarity: 0.6670485734939575
#
# いつか森高千里さんみたいな女性になってね
# Similarity: 0.589002251625061
#
#
# Similarity: 0.9999997615814209
#
#  ｢いつおばさんになるの｣な森高千里さんから｢かわいい｣言われたら、そりゃ興奮するよね
# Similarity: 0.6383671164512634
#
#
# Similarity: 0.9999997615814209
#
# よかったじゃん
# Similarity: 0.605944812297821
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# 久保さん、こんばんはっ！ 今週は、森高さんのお話からですね！
# Similarity: 0.6303694844245911
#
# かわいいをいただきました👏
# Similarity: 0.6568998098373413
#
# 久しぶりの.........
# Similarity: 0.6568738222122192
#
# 森高千里さんあの年齢であの可愛さはバグだよね
# Similarity: 0.6336266994476318
#
# うそだ
# Similarity: 0.6074973344802856
#
#
# Similarity: 0.9999997615814209
#
# 森高さんから  "かわいかった"
# Similarity: 0.6789459586143494
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# 「可愛いいただきました」いただきました。
# Similarity: 0.6551397442817688
#
# 久保ちゃん可愛いよほんとに
# Similarity: 0.6316916346549988
#
# 可愛い頂きました
# Similarity: 0.5982462763786316
#
# 正隨が桐蔭出身というとこまではリサーチ済みと予想。
# Similarity: 0.7066314220428467
#
# おめでとうございます笑
# Similarity: 0.6966215372085571
#
# かわいいいただいて喜ぶ久保ちゃんかわいい
# Similarity: 0.679515540599823
#
# 可愛いをいただきました。
# Similarity: 0.6228347420692444
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# おー！森高さんにご挨拶！！
# Similarity: 0.6334928274154663
#
# 森高さんにFNSのお礼を言いにいった話かと思いきや かわいいと言ってもらえたはなしだったようです
# Similarity: 0.6347708702087402
#
# 森高千里さんと乃木坂のコラボ見てるときに改めて思ったけどマジで10〜20代のアイドルと並んでるのになんでこんなに綺麗なの？！って思った
# Similarity: 0.6326518058776855
#
# すんばらしく
# Similarity: 0.7684454321861267
#
#
# Similarity: 0.9999997615814209
#
# 『私がオバさんになっても』をお風呂で歌ってる久保ちゃん可愛すぎでしょ
# Similarity: 0.6190776824951172
#
# 森高さんから可愛いもらった久保ちゃん最強やん
# Similarity: 0.683885931968689
#
# 史緒里さんがおばさんになってもおでは愛し続けるえ🫶
# Similarity: 0.658212423324585
#
#
# Similarity: 0.9999997615814209
#
# 問題なく出席。 森高千里さんから「カワイイ！」と言われた話から。
# Similarity: 0.7130630612373352
#
# やったね
# Similarity: 0.5665943026542664
#
#  annm10の森高千里さんと会った話から始まった
# Similarity: 0.687920868396759
#
# 恋すぎる
# Similarity: 0.6673091053962708
#
# 最高でした！
# Similarity: 0.629324197769165
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# 12月も残り半分ですね。
# Similarity: 0.5894438028335571
#
# 生歌やん 可愛いやん 応援されてるやん うれしいいいい
# Similarity: 0.6571837663650513
#
# FNSでコラボしたもんね✨😊 森高千里さんは奇跡！！
# Similarity: 0.6514678597450256
#
# 今年も残り半月…
# Similarity: 0.6352612972259521
#
# 久保ちゃんはかわいいよ。
# Similarity: 0.5990003347396851
#
# さぁ 今からは 乃木坂46ANN📻 3時まで  それから 1時間 休憩してから 運命のサッカーだ‼️
# Similarity: 0.664739727973938
#
# 森高千里様から「かわいい」戴いたw
# Similarity: 0.7128995656967163
#
# お風呂で熱唱www
# Similarity: 0.7468948364257812
#
# いつまで経ってもオバサンにならないことで知られる
# Similarity: 0.6639167666435242
#
#
# Similarity: 0.9999997615814209
#
# かわいい頂きました
# Similarity: 0.6058886051177979
#
# 12月も残り半分ですね！
# Similarity: 0.6473032832145691
#
#
# Similarity: 0.9999997615814209
#
# クリスマスまであと10日！
# Similarity: 0.653999388217926
#
#
# Similarity: 0.9999997615814209
#
# かわいい頂きましたw
# Similarity: 0.6423407793045044
#
#
# Similarity: 0.9999997615814209
#
# 歌ってくれるの...ｱﾘｶﾞﾄｳｺﾞｻﾞｲﾏｽ!!
# Similarity: 0.6485342979431152
#
#  きたー!
# Similarity: 0.6064532995223999
#
# お風呂で熱唱〜
# Similarity: 0.6314931511878967
#
# 森高さんってホント凄いよなぁ
# Similarity: 0.6511234045028687
#
# 生放送スタート。森高千里さんに挨拶に行ったらしい久保史緒里さん。かわいいと言われて大喜びしている久保史緒里さん。なるほど。
# Similarity: 0.691330075263977
#
#
# Similarity: 0.9999997615814209
#
#  森高千里さんからかわいいをいただきました👏
# Similarity: 0.6244210004806519
#
# 久保ちゃんが歌う私がおばさんになっても聞きたい！！
# Similarity: 0.6215288043022156
#
# しおりちゃんかわいいです!
# Similarity: 0.6432443857192993
#
# 私がおばさんになってもを歌っていたしおちゃん
# Similarity: 0.6524380445480347
#
#   お風呂で歌ってんだw  一瞬の歌声、耳が喜んどる。
# Similarity: 0.6288416981697083
#
# 突然の生歌カットイン。
# Similarity: 0.635322630405426
#
# 今の一節だけで歌うまいのがわかる。続き聞かせてくれえぇぇぇ
# Similarity: 0.6298816800117493
#
# この歌好きっす
# Similarity: 0.66875159740448
#
# ちょっと歌ったのがめっちゃ上手い！
# Similarity: 0.6089529991149902
#
# 「何するの？クリスマス」
# Similarity: 0.6938650608062744
#
# ファッ！？ 半月！？
# Similarity: 0.6455819606781006
#
# 出だしは好調やね！
# Similarity: 0.6391612887382507
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# 久保ちゃんがオバさんになっても好きですよ！！
# Similarity: 0.5947622060775757
#
# かわいいっ
# Similarity: 0.6543917655944824
#
# かわいいよん
# Similarity: 0.6660513281822205
#
# 可愛い頂きました
# Similarity: 0.5982462763786316
#
# 森高さん、全然おばさんになってないんだよな
# Similarity: 0.6388155817985535
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# おめでとうございます
# Similarity: 0.6868230700492859
#
# カワイイいただきましたw
# Similarity: 0.6585254073143005
#
# 言霊砲か（ちょっと違う）
# Similarity: 0.6759744882583618
#
#
# Similarity: 0.9999997615814209
#
# クリスマスは何をする？
# Similarity: 0.6273224353790283
#
# 森高千里綺麗だよねー 歳取らないよねー
# Similarity: 0.6753503680229187
#
#
# Similarity: 0.9999997615814209
#
#
# Similarity: 0.9999997615814209
#
# 今週は久保史緒里さん1人ですか。いや、鷲尾ちゃんと2人ですね。たぶん(笑)。
# Similarity: 0.6333413124084473
#
#  森高千里さんから「可愛い」をいただいたのね🤭
# Similarity: 0.6149142384529114
#
# 森高さんから可愛いを頂いた久保さん 秋元真夏さん大嫉妬案件ですwww
# Similarity: 0.6934910416603088
#
# 森高さんから可愛いをいただいた久保ちゃん！
# Similarity: 0.6006361246109009
#
# 久保ちゃん褒められてデレデレでかわいいな
# Similarity: 0.66851806640625
#
#
# Similarity: 0.9999997615814209
#
# かわいいって言われて嬉しそうなしーちゃんかわいい！！
# Similarity: 0.6750276684761047
#
#  森高さんから可愛い貰って饒舌になられてる今お聞きのラジオのパーソナリティは乃木坂46の久保史緒里さんです。
# Similarity: 0.6067918539047241
#
# お綺麗な方から可愛いいただけるのは嬉しいよなあ
# Similarity: 0.6615405082702637
#
# しおりちゃんかーいーー
# Similarity: 0.6168301701545715
#
# しーちゃんやっぱ上手すぎる〜
# Similarity: 0.6555286645889282
#
# 森高さんが乃木坂ちゃんに可愛いは可愛いの乱反射だろ
# Similarity: 0.6586042642593384
#
# 怖い話しないでください
# Similarity: 0.6990078687667847
#
#
# Similarity: 0.9999997615814209
#
# やめろしおりそれは聞いちゃダメだ
# Similarity: 0.5968186855316162
#
# 久保「クリスマス、何するの？」 ワイ「あなたとミーグリですけど」
# Similarity: 0.7127124071121216
#
# あとで聞きます笑笑
# Similarity: 0.6537885665893555
#
# クリスマスがあと10日!?!?!?
# Similarity: 0.6339218020439148
#
# でも森高さん一生オバサンにならないよね
# Similarity: 0.6154835224151611
#
# 森高さんお綺麗だよなぁ
# Similarity: 0.6748300194740295
#
# 私がオバサンになっても 今日の１曲決まったな
# Similarity: 0.6464493870735168
#
# クリスマス？ミーグリに決まってるじゃないですか。
# Similarity: 0.5694811940193176
#
#
# Similarity: 0.9999997615814209
#
#  ありがとうございます
# Similarity: 0.6945504546165466
#
# (*-ω-)ｳﾝｳﾝ♪  私がオバさんになっても 良いよね〜
# Similarity: 0.6827596426010132
# Average similarity: 0.738300142919316
# やかましいわ
# 久保ちゃん、それ聞いちゃおしまいよ
# Similarity: 0.7089006304740906
# やかましいわ
#  頑張っちゃってください
# Similarity: 0.7347619533538818
# やかましいわ
# クリスマスこのままだとボッチ…
# Similarity: 0.6660522818565369
# やかましいわ
# 何もしないよ
# Similarity: 0.6846131682395935
# やかましいわ
# 森高さん若いよなぁー。
# Similarity: 0.6966256499290466
# やかましいわ
# ちゃんくぼ「私がオバさんになっても」ヘビロテ中w
# Similarity: 0.6543564200401306
# やかましいわ
# クリスマス？バイトですよ？
# Similarity: 0.6917007565498352
# やかましいわ
#
# Similarity: 0.615548849105835
# やかましいわ
# あなたと話すんです
# Similarity: 0.6621712446212769
# やかましいわ
# 森高千里さんからかわいいいただきました、ありがとうございます
# Similarity: 0.6913744807243347
# やかましいわ
#
# Similarity: 0.615548849105835
# やかましいわ
# ミーグリだよ！！！😁😎
# Similarity: 0.6765204668045044
# やかましいわ
#
# Similarity: 0.615548849105835
# やかましいわ
# 森高千里さんからかわいい頂きました。 ありがとうございます。
# Similarity: 0.6663837432861328
# やかましいわ
# かわいいーーーー
# Similarity: 0.7421844005584717
# やかましいわ
# え、なにらじお？
# Similarity: 0.7430056929588318
# やかましいわ
# 森高さん綺麗だよね。
# Similarity: 0.6940461993217468
# やかましいわ
# クリスマス…はて？
# Similarity: 0.7204433679580688
# やかましいわ
# 森高千里さんに可愛い頂いたんだ笑
# Similarity: 0.6990060806274414
# やかましいわ
# クリスマスが今年も〜
# Similarity: 0.6485437154769897
# やかましいわ
# 可愛い女性の皮を被ったナニカ
# Similarity: 0.5974549055099487
# やかましいわ
# 私がオバさんなっても 本当に良すぎる……
# Similarity: 0.7048385739326477
# やかましいわ
# クリスマスはミーグリっすね
# Similarity: 0.719372034072876
# やかましいわ
# 早速、森高さんの話題。
# Similarity: 0.6246867775917053
# やかましいわ
# 森高千里さんから「かわいい」のお言葉をいただいた久保史緒里さん
# Similarity: 0.6731956005096436
# やかましいわ
# いただけるものはいただいておこう。
# Similarity: 0.7229869961738586
# やかましいわ
# オメデトウゴザイナス
# Similarity: 0.644265353679657
# やかましいわ
# クリスマス、、、 耳が痛いよ
# Similarity: 0.7188937067985535
# やかましいわ
# 乃木坂46のオールナイトニッポン | ニッポン放送
# Similarity: 0.6103683114051819
# やかましいわ
# 森高千里はほんとオバサンにならんよなぁ
# Similarity: 0.691521406173706
# やかましいわ
# 毎日お風呂で私がオバさんになっても歌ってるの可愛い
# Similarity: 0.6992110013961792
# やかましいわ
# ？:あ〜 ありがとうございます〜 森高千里からかわいいをいただきました こんなんなんぼあってもええですからね
# Similarity: 0.7037389874458313
# やかましいわ
#
# Similarity: 0.615548849105835
# やかましいわ
#
# Similarity: 0.615548849105835
# やかましいわ
# 毎日歌ってる!？笑
# Similarity: 0.6712055206298828
# やかましいわ
# クリスマス何するの…？w
# Similarity: 0.658627986907959
# やかましいわ
# スモールクリスマスツリーを飾ったしーちゃん。
# Similarity: 0.6432542204856873
# やかましいわ
#
# Similarity: 0.615548849105835
# やかましいわ
# ミーグリ
# Similarity: 0.6136001348495483
# やかましいわ
#   こりゃ頑張れるねぇ。
# Similarity: 0.6983457803726196
# やかましいわ
# かわいい、をいただいて喜ぶ久保先生
# Similarity: 0.7514424324035645
# やかましいわ
# 久保ちゃんのお風呂でのワンマンライブが聞きたい笑
# Similarity: 0.6588475704193115
# やかましいわ
#  てか、軽く歌って上手いなぁ、おい！！
# Similarity: 0.7075806856155396
# やかましいわ
# あと10日でクリスマス？？？？？ しらんそれ
# Similarity: 0.7258109450340271
# やかましいわ
# 森高千里さんに可愛いいただいただね！🤣
# Similarity: 0.7052288055419922
# やかましいわ
#
# Similarity: 0.615548849105835
# やかましいわ
# もう2022年終わるやんｷﾂ…
# Similarity: 0.734891951084137
# やかましいわ
#
# Similarity: 0.615548849105835
# やかましいわ
# 仕事です
# Similarity: 0.7271178960800171
# やかましいわ
# 森高さんからかわいい😍いただいた 久保史緒里さん！
# Similarity: 0.6849014163017273
# やかましいわ
# ああ、見たわ。たしかに年齢とか信じられないくらい可愛かったな。
# Similarity: 0.6532476544380188
# やかましいわ
# 何回言うねんw
# Similarity: 0.7068600058555603
# やかましいわ
# クリスマスイブは寂しく職場に泊まりだね
# Similarity: 0.675148606300354
# やかましいわ
#
# Similarity: 0.615548849105835
# やかましいわ
# 森高千里さんから「かわいい」を頂戴した久保史緒里さん
# Similarity: 0.6766098737716675
# やかましいわ
# 「久保ちゃん、かわいい」 本人大変喜んでおります。
# Similarity: 0.659056544303894
# やかましいわ
# 森高さんから「かわいい」頂きました！ 久保ちゃん嬉しそう
# Similarity: 0.7017250657081604
# やかましいわ
# コラボ…あ。他局の音楽ラジオのテーマに使えるぞ
# Similarity: 0.703804075717926
# やかましいわ
# あの！森高千里さんから「可愛い」
# Similarity: 0.7417997717857361
# やかましいわ
# いつ、おばさんになるのでしょう？
# Similarity: 0.6978638172149658
# やかましいわ
#   の時間がやってきました。今日の生放送は、作業をしながら聴くので、リアタイはしてますけど、実況ツイートはしないで聴くことにします。というわけで、  さんから「かわいい」を頂いた  さんの声に癒されながら作業を進めますｗ
# Similarity: 0.6485822796821594
# やかましいわ
# それは素晴らしい😂 間違いなく可愛い☺️
# Similarity: 0.6971683502197266
# やかましいわ
#
# Similarity: 0.615548849105835
# やかましいわ
# 生歌ジャック笑
# Similarity: 0.6977942585945129
# やかましいわ
# ん？しおりさんとミーグリ それ以外？ないよ？？ぼっちニートオタクだからね😃
# Similarity: 0.6991969347000122
# やかましいわ
# ケーキぐらいは食べようかな…
# Similarity: 0.7166396379470825
# やかましいわ
# くぼちゃん、おばさんになっても変わらず愛するよ
# Similarity: 0.739876389503479
# やかましいわ
# ？？？｢あー、ありがとうございます、ねっ、今かわいいをいただきましたけどもね｣
# Similarity: 0.6659002304077148
# やかましいわ
# ツリーでQOL
# Similarity: 0.6140086054801941
# やかましいわ
# こわいこわい
# Similarity: 0.6952967047691345
# やかましいわ
# 森高さんから可愛いいただきました
# Similarity: 0.6652815937995911
# やかましいわ
# やっぱり今日はテンション高い！笑 素敵なお仕事ばかりで良い一日だったね☺️
# Similarity: 0.6649105548858643
# やかましいわ
# オタクにクリスマスの話しない方がいいよ(偏見)
# Similarity: 0.6874147057533264
# やかましいわ
# しーちゃんは永遠におばさんにならないよ？？
# Similarity: 0.691880464553833
# やかましいわ
# 今週は島内謎のFA宣言の話すると予想
# Similarity: 0.6191452145576477
# やかましいわ
# 森高千里さんは、ほんま綺麗よな
# Similarity: 0.7590306401252747
# やかましいわ
# おっ！シュトーレン！
# Similarity: 0.7184354066848755
# やかましいわ
# しおちゃん、よろよろっち〜😍💕💕
# Similarity: 0.6650394797325134
# やかましいわ
# 「ワタシがおばさんになっても」久々に聴くといいよね～👍️
# Similarity: 0.7187500596046448
# やかましいわ
#
# Similarity: 0.615548849105835
# やかましいわ
# あと半月で終わってしまうのか今年。
# Similarity: 0.6492367386817932
# やかましいわ
# ん？クリスマスって中止になったはずじゃ
# Similarity: 0.5918024182319641
# やかましいわ
# 残り半月、、、、。
# Similarity: 0.5931074023246765
# やかましいわ
#
# Similarity: 0.615548849105835
# やかましいわ
# 森高さん、お綺麗だよね^ ^
# Similarity: 0.6909759640693665
# やかましいわ
#
# Similarity: 0.615548849105835
# やかましいわ
# 可愛い頂きましたーw
# Similarity: 0.6897244453430176
# やかましいわ
# ニートは誕生日もクリスマスも正月も通常運転です
# Similarity: 0.6469241976737976
# やかましいわ
# オコエの話とか来るかな？
# Similarity: 0.6921428442001343
# やかましいわ
#
# Similarity: 0.615548849105835
# やかましいわ
# 「あの森高千里さんからかわいい頂きました！」w
# Similarity: 0.6698989868164062
# やかましいわ
# 森高さんに可愛いを頂いたくぼちゃん。
# Similarity: 0.6497094035148621
# やかましいわ
# 初っ端から飛ばしてますなあ
# Similarity: 0.6563727259635925
# やかましいわ
#  今年もう15日で終わんのかよ…  クリスマスまであと10日…………
# Similarity: 0.7063785195350647
# やかましいわ
# クリスマスはミーグリだよ！？！？
# Similarity: 0.650626540184021
# やかましいわ
# クリスマスがやってくる〜
# Similarity: 0.6149381399154663
# やかましいわ
# その話やめてね
# Similarity: 0.7121766209602356
# やかましいわ
# クリスマスツリー（ほぼ枝）
# Similarity: 0.6043482422828674
# やかましいわ
# 森高さん…。その通りですよ。
# Similarity: 0.677936315536499
# やかましいわ
# クリスマスはミーグリです！！
# Similarity: 0.6791040301322937
# やかましいわ
# ぼっちだーーーーーい
# Similarity: 0.7401626706123352
# やかましいわ
# クリスマス？有馬記念やろ
# Similarity: 0.6602511405944824
# やかましいわ
#
# Similarity: 0.615548849105835
# やかましいわ
# クリスマスがあと10日⁉︎
# Similarity: 0.6402407288551331
# やかましいわ
# クリスマスパーティーする？
# Similarity: 0.6624528765678406
# やかましいわ
# クリスマス?それなーにー? 卒検だよ
# Similarity: 0.6911162734031677
# やかましいわ
#
# Similarity: 0.615548849105835
# やかましいわ
# 小っちゃいクリスマスツリー
# Similarity: 0.7416248917579651
# やかましいわ
# 私は毎日史緒里ちゃんに"かわいい"送っております😘😘
# Similarity: 0.6566961407661438
# やかましいわ
# めっちゃ追い込んできますやん
# Similarity: 0.7608898878097534
# やかましいわ
# クリスマス？何それ美味しいの？
# Similarity: 0.6774425506591797
# やかましいわ
# 森高さんから可愛いもらった？  可愛い貯金しないとじゃん！(先代か)
# Similarity: 0.717684805393219
# やかましいわ
# あと10日でクリスマス、、？
# Similarity: 0.6598780751228333
# やかましいわ
#
# Similarity: 0.615548849105835
# やかましいわ
# クリスマスはミーグリですけど？？
# Similarity: 0.6609508395195007
# やかましいわ
# ありがとうございなす にしか聞こえない
# Similarity: 0.7214316129684448
# やかましいわ
# 久保ちゃんが 小さいクリスマスツリーを買った…？
# Similarity: 0.6540015935897827
# やかましいわ
# それお風呂で歌わないで公共の場で歌ってくれないか
# Similarity: 0.6918134689331055
# やかましいわ
# クリスマスとは…？
# Similarity: 0.6322444081306458
# やかましいわ
# クリスマスはミーグリだろ？？？
# Similarity: 0.6555054783821106
# やかましいわ
# シュトーレン
# Similarity: 0.5913246870040894
# やかましいわ
# バイトですけど何か？笑
# Similarity: 0.6767224669456482
# やかましいわ
# ほんっっとに綺麗だったな森高さん 乃木坂にいて遜色なかった
# Similarity: 0.7031039595603943
# やかましいわ
# クリスマス暇だわ〜
# Similarity: 0.6956622004508972
# やかましいわ
# 野郎達とケンタッキーパーティーやるけど
# Similarity: 0.69607013463974
# やかましいわ
# クリスマスはミーグリですよ←
# Similarity: 0.6845023036003113
# やかましいわ
# クリスマスは当然ぼっちです！！
# Similarity: 0.6994619369506836
# やかましいわ
#
# Similarity: 0.615548849105835
# やかましいわ
# @null 森高千里から可愛いやら頑張れ言われたら久保ちゃん嬉しいわなそりゃ…！
# Similarity: 0.6890486478805542
# やかましいわ
# もしかしてそのツリー43型より大きいのか？
# Similarity: 0.635357677936554
# やかましいわ
# クリスマスの予定はありません！
# Similarity: 0.6651540398597717
# やかましいわ
# 24日 影ちゃんとデート 25日 与田ちゃんとデート
# Similarity: 0.6054887175559998
# やかましいわ
# クリスマス・・・？
# Similarity: 0.6897755265235901
# やかましいわ
# しゅとーれん？
# Similarity: 0.6883202791213989
# やかましいわ
# 久保史緒里さんも可愛いです😍
# Similarity: 0.685279905796051
# やかましいわ
#
# Similarity: 0.615548849105835
# やかましいわ
# くぼさまウチら煽ってます？笑
# Similarity: 0.6527072191238403
# やかましいわ
#
# Similarity: 0.615548849105835
# やかましいわ
# 12月あと半分……？
# Similarity: 0.6791319847106934
# やかましいわ
# しーちゃんデレデレすぎるぞ...！！
# Similarity: 0.7051900625228882
# やかましいわ
# ミーグリだよ！！！！！！！
# Similarity: 0.7284104228019714
# やかましいわ
# クリスマスはバイト😀
# Similarity: 0.6430146098136902
# やかましいわ
# 仕事だ…………
# Similarity: 0.7290890216827393
# やかましいわ
# クリスマスはミーグリです()()()()()(
# Similarity: 0.6585847735404968
# やかましいわ
# クリスマスは帰省です
# Similarity: 0.6689893007278442
# やかましいわ
# 何もありません、 クリスマスは年末で苦しみます
# Similarity: 0.6171173453330994
# やかましいわ
# クリスマス。はて？
# Similarity: 0.7047215104103088
# やかましいわ
# 　 クリスマスってなあに？
# ...
# またねー！
# Similarity: 0.7281880378723145
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# 本日もオツカレサマデシタ！ LINE LIVEも楽しかったよ。
# Similarity: 0.6488390564918518
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# お疲れ様でした。
# Similarity: 0.44087401032447815
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# オツカレサマデシタ〜
# Similarity: 0.7062689065933228
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# 今週もLINE LIVEからの2時間のラジオ生放送オツカレサマデシタ。 久しぶりの１人喋りでもめっちゃオモロカッタです。  来週のゲスト回も楽しみっす。
# Similarity: 0.7581145763397217
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
#  オツカレサマデシタ
# Similarity: 0.6964747905731201
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# オツカレサマデシタ
# Similarity: 0.6964747905731201
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# またね〜
# Similarity: 0.6784999370574951
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# オツカレサマデシタ
# Similarity: 0.6964747905731201
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# 久保ちゃん、乃木坂46ANNスタッフの皆さん今夜も2時間お疲れさまでした😌❤️
# Similarity: 0.8366672992706299
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# お疲れ様でした〜！ 来週は、飛鳥ちゃんにれんたんに与田ちゃんがゲストだから楽しみ〜🎶 またね〜👋
# Similarity: 0.8215458393096924
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# あっというまの2時間でした くぼちゃんまたね！
# Similarity: 0.7528153657913208
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# またね〜
# Similarity: 0.6784999370574951
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# 今週は久しぶりのおひとりラジオで、しばらくぶりのコーナーがいくつかありましたね！！💦 スポーツの話が9割だった記憶です☺️ 青春のコーナーはやっぱりいいなぁ笑 来週は飛鳥ちゃん、よだっちょ、れんたんがゲスト！！ 来週も楽しみにしてます！！またねー！！👋✨
# Similarity: 0.8311185240745544
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# またねー
# Similarity: 0.6946607828140259
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# 来週SHOWROOM復活してくれ！！
# Similarity: 0.7304717302322388
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
#  ピッ！オツカレサマデシタ。 またね〜。 元気な久保ちゃんが堪能出来ました。
# Similarity: 0.7565557956695557
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
#  オツカレサマデシタ！来週は寝坊厳禁！絶対にリアルタイムで聴くぞ
# Similarity: 0.7748722434043884
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# オツカレサマデシタ…！ 久々の通常回1人喋り、好きを真っ直ぐに少し饒舌に語る時間がとっても好きだなぁと。 今週もあっという間でした︎︎︎︎︎☺︎  来週も元気に！またこの時間に~
# Similarity: 0.8062437772750854
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# またねぇ〜
# Similarity: 0.7090204954147339
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# 久保ちゃんお疲れ様でした！！
# Similarity: 0.7257542610168457
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# またねー！ オツカレサマデシタ！
# Similarity: 0.7642972469329834
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# またね～👋  来週は飛鳥ちゃん！
# Similarity: 0.7994912266731262
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# またねー！👋
# Similarity: 0.7514840960502625
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# くぼしお疲れした〜！ 次はやんに見せつけましょう！かっけー先輩の姿を！
# Similarity: 0.79976487159729
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# 来週飛鳥ちゃん来るー！！！！！！！
# Similarity: 0.7950198650360107
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# 森高千里さんに可愛いと言われ喜ぶ久保ちゃんから始まり、Going!ばりのスポーツトーク、出来た後輩やんちゃんとここでもツイてない先輩久保ちゃんの焼肉エピソード、鷲尾ちゃん登場、青春のコーナー、、 久々の一人喋りお疲れ様でした!! 来週はメンバー4人トーク!楽しみや
# Similarity: 0.8567776679992676
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# フランス対モロッコだぁぁぁぁぁぁぁぁぁぁ
# Similarity: 0.7915260791778564
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# @null 久保ちゃん1人回お疲れっした！！　またねー！！
# Similarity: 0.8272422552108765
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# 乃木坂46齋藤飛鳥・岩本蓮加・与田祐希「ANN」生出演決定  ▼写真・記事詳細はこちら       @nogizaka46 @NOGI46ann
# Similarity: 0.9244595170021057
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
#   LINELIVEからお疲れ様でした。 来週の飛鳥さん達との会話楽しみです。 またね〜。 おやすみなさい。
# Similarity: 0.6761603355407715
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# おい！野球太郎寝落ちしただろ！ 久保ちゃんのおかげでエンディングで1人ファンが増えたって言うのに
# Similarity: 0.7752362489700317
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# 来週飛鳥オールナイトニッポンくるの熱う
# Similarity: 0.7958400845527649
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# またねー可愛い定期
# Similarity: 0.7166262865066528
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# 来週は飛鳥ちゃんのまたね〜が聞けるんか😙
# Similarity: 0.8091903924942017
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# またね〜👋🏻
# Similarity: 0.7408201694488525
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# くぼさん今夜もオツカレサマデシタ！だいぶ寒いので、暖房チャレンジが気になって仕方がないです！次回はついに飛鳥さん！！！ペニンシュラのマンゴープリン買ってきましょう！！
# Similarity: 0.8067653179168701
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# お疲れ様でした。 またね～
# Similarity: 0.5414637327194214
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# またねー🤗
# Similarity: 0.7124823331832886
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# 久保ちゃんオツカレサマデシタ！ 来週はゲストで飛鳥ちゃん、与田ちゃん、れんたん！
# Similarity: 0.8378581404685974
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# またねー
# Similarity: 0.6946607828140259
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# またね〜‼️
# Similarity: 0.7740429639816284
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
#  マタネ！
# Similarity: 0.6856229305267334
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# またね～👋
# Similarity: 0.7650619745254517
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
#  そういえば、久保ちゃんってまだ暖房チャレンジしてるのかしら？
# Similarity: 0.7135605216026306
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# 来週がどんな感じになるのか、楽しみで楽しみで。 この夢が「オールナイト」の部分だけ叶おうとしているかもしれない… あすちゃんにとって楽しくて充実した回になりますように。
# Similarity: 0.7551169395446777
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# オツカレサマデシタ！
# Similarity: 0.7736509442329407
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# 誰に頼まれたわけでもないのに，番組で『野球太郎』を推しまくる久保ちゃんのくだりを聴くと，ヤクルト1000を推してた新内を思い出す．スポンサーになってくれるまで，もうひと押し（？）
# Similarity: 0.7977803945541382
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# 今週もお疲れ様でした！ 来週楽しみにしてます
# Similarity: 0.7474069595336914
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# オツカレサマデシタ〜
# Similarity: 0.7062689065933228
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# お疲れ様でした！
# Similarity: 0.5976467132568359
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
#    くぼしー、2週間ぶりの1人での生放送中オツカレサマデシタ！✨  今週もスポーツずくめの2時間でした！⚽️⚾️
# Similarity: 0.8247848749160767
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# またね〜🖐🏻(*^^*)
# Similarity: 0.7936881184577942
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# またね〜！
# Similarity: 0.72324138879776
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# お疲れ様でした〜
# Similarity: 0.6068307161331177
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# オツカレサマデシタ
# Similarity: 0.6964747905731201
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# またね！
# Similarity: 0.7040147185325623
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# おつかれさまでした またね〜(´▽`)ﾉ
# Similarity: 0.7429845333099365
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# おつかれさまでした！！！
# Similarity: 0.7478777766227722
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# 是非、このあとのフランス戦も… 久保ちゃんなら観そうだな  モドリッチ覚えてくれたの嬉しいんで3位決定戦も応援して下さいな
# Similarity: 0.7679415345191956
# 『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソナリティを担当する久保史緒里と同期の岩本蓮加と与田祐希も登場      @NOGI46ann @nogizaka46  ▼写真・記事の詳細はこちら
# またね〜！
# Similarity: 0.72324138879776
# Average similarity: 0.7420515816707116
# またねー
# しおりんお疲れ様でした〜！ 来週も絶対聴く！👂 またね〜(´▽`)ﾉ
# Similarity: 0.8337456583976746
# またねー
# 今日も安定の爆笑させてもらったw 久保ちゃんお疲れ様でした！
# Similarity: 0.7216625213623047
# またねー
#   来週のゲストは飛鳥ちゃん！ （と岩本さんと与田っちょ）  またね〜👋
# Similarity: 0.8239068984985352
# またねー
# オツカレサマデシタ メンバー回もいいですが、 1人回も久保さんの超絶怒涛のべしゃり が聴けてよかったです。
# Similarity: 0.7592341899871826
# またねー
# オツカレサマデシタ！！
# Similarity: 0.7683268785476685
# またねー
#  が始まりましたが、  の後半は睡魔と闘いながらリアタイして、もう限界に来ていますので、今週はここで「おやすみ～」といきます。あとで、タイムシフトで聴くことにします。船員、クルーの皆さんごめんなさい...(笑)いろいろ、  についても聴きたいけど
# Similarity: 0.7730630040168762
# またねー
# またね〜
# Similarity: 0.8838534951210022
# またねー
# まあ、正直なとこ久保ちゃんと飛鳥ちゃんのサシで2時間トークも聴いてみたかったけど、話が弾むとこがイマイチ想像つかないってのも正直なとこ。
# Similarity: 0.7494549751281738
# またねー
# 来週、最高！！楽しみ
# Similarity: 0.749858558177948
# またねー
# ききながらバスラ申し込み ((꜆꜄ ˙꒳˙)꜆꜄꜆ﾎﾟﾁﾎﾟﾁﾎﾟﾁﾎﾟﾁﾎﾟﾁ してた·····w
# Similarity: 0.684532105922699
# またねー
# またね〜👋
# Similarity: 0.8529015779495239
# またねー
# またね〜
# Similarity: 0.8838534951210022
# またねー
# お疲れ様でした
# Similarity: 0.5331148505210876
# またねー
# 今週もお疲れ様でしたー！ 野球だけでなくサッカーの話題に興味を持ってくれてるの嬉しいなー！ 来週は飛鳥ちゃん、れんたん、与田ちゃん！！ 楽しみだな〜！
# Similarity: 0.7766321301460266
# またねー
# またね〜
# Similarity: 0.8838534951210022
# またねー
# 今週もお疲れ様でした🥺 やんちゃんとの次回のご飯の報告も心待ちにしてます！ 野球太郎さんポチるか検討します！笑 来週も楽しみにしてますね〜 ゆっくり休んでください。 またね〜👋
# Similarity: 0.794567346572876
# またねー
# 久保ちゃんオツカレサマデシタ🍵
# Similarity: 0.8040183782577515
# またねー
# 結局、最後まで聴いてしまった。来週はあしゅが来るらしい。
# Similarity: 0.8099207878112793
# またねー
# 来週が楽しみでならない男、見参 しーちゃん リアタイ勢の皆さんお疲れ様でした！ またね〜(´▽`)ﾉ
# Similarity: 0.7981709241867065
# またねー
# ピッ！オツカレサマデシタ✋ 久々の1人喋りも良いね✨😊 鷲尾ちゃん暴走してたけど笑 来週は飛鳥ちゃん、与田ちゃん、蓮加ちゃんがゲスト登場！！ またねー！✋
# Similarity: 0.8265966773033142
# またねー
# お疲れ様でした 野球見るかどうかは別かな
# Similarity: 0.7594273686408997
# またねー
# 乃木坂46のオールナイトニッポン | ニッポン放送
# Similarity: 0.679185152053833
# またねー
#    ニッポン放送の制作で全国の皆様にお送りした『乃木坂46・ちゃんくぼのオールナイトニッポン』  今週の放送はこれにて  へいか～い！  最後までお聴き頂きありがとうございました！  ＊明日は『ナイナイのオールナイトニッポン（  ）』をお送りします
# Similarity: 0.7440909147262573
# またねー
# オツカレサマデシタ 野球太郎からもいいねもらえたので、準決まで見て寝ます
# Similarity: 0.7462512254714966
# またねー
# オツカレサマデシタ！
# Similarity: 0.7987666726112366
# またねー
# またね〜！！
# Similarity: 0.8688941597938538
# またねー
# ほぼスポーツ番組と化した今日でしたが楽しかったです😂 来週は飛鳥ちゃんに与田ちゃんとれんたん！今から楽しみです！ 今週もオツカレサマデシタ！
# Similarity: 0.7972490787506104
# またねー
#  来週もリアタイだなー
# Similarity: 0.8275772929191589
# またねー
# 今週も良かった!! いずいのコーナーを久しぶりに聴きたくなってきた笑  そして来週は飛鳥ちゃん、蓮加に与田ちゃんが出るから楽しみ♪
# Similarity: 0.805838406085968
# またねー
# しーちゃん、今週お疲れ様でした♪ 久しぶりのコーナーもあって楽しかったです。
# Similarity: 0.7894476652145386
# Average similarity: 0.7842665294806163
# 敗者復活でやるような場所じゃない
# 久保ちゃんお疲れ様でした🎵 ソロはひさびさでしたね  来週はとうとう飛鳥さんが 映像研以来の御登場！ れんたんよだちゃんも来てくれるなんて 楽しみでしかないよ😁 またね～👋👋
# Similarity: 0.7557250261306763
# 敗者復活でやるような場所じゃない
# 今週も楽しい放送をありがとうございました。お疲れ様でした。
# Similarity: 0.6201602816581726
# 敗者復活でやるような場所じゃない
# 楽しみすぎるて
# Similarity: 0.7196718454360962
# 敗者復活でやるような場所じゃない
# しーちゃんお疲れ様でした！ また来週ー
# Similarity: 0.6802039742469788
# 敗者復活でやるような場所じゃない
# またねー
# Similarity: 0.6773365139961243
# 敗者復活でやるような場所じゃない
# またね〜
# Similarity: 0.662911593914032
# 敗者復活でやるような場所じゃない
# おごりのカッコいい払い方って難しいけど、だからこそかっこいいのかな？ ちゃんとスポーツ観戦してみたいなと思いました！ 来週は4人ということでわちゃわちゃの予感です！
# Similarity: 0.8507862091064453
# 敗者復活でやるような場所じゃない
# お疲れ様でした
# Similarity: 0.5036484003067017
# Average similarity: 0.6838054805994034
# しおりさん、スタッフさんオツカレサマデシタ！！ 久々の1人喋りスポーツの話満載でしたが色んな方向にお話広がって、楽しかったです 来週、念願の飛鳥さんゲスト！！れんかちゃんも代打以外でのしおりさんMCでのゲストは初！先週に引続き与田ちゃんと！最高に楽しみです！ また来週〜👋
# 12/14㈬     続き 3時~元テレ東P[ 📹無料映像配信も【HAKUNA Live】👉  📩投稿はsakuma@allnightnippon.com▶
# Similarity: 0.8309058547019958
# しおりさん、スタッフさんオツカレサマデシタ！！ 久々の1人喋りスポーツの話満載でしたが色んな方向にお話広がって、楽しかったです 来週、念願の飛鳥さんゲスト！！れんかちゃんも代打以外でのしおりさんMCでのゲストは初！先週に引続き与田ちゃんと！最高に楽しみです！ また来週〜👋
# なんだ、この『野球太郎』宣伝ラジオｗ 　　ポチっていただいた方もありがとうございました！　でも、弊誌を買ってもWBCについていい情報を得られないですが、そのかわりに10数年後に侍ジャパンに入るかもいれない、中学生、高校生、大学生を知ることはできるので、それでよければm(_ _)m
# Similarity: 0.838800847530365
# Average similarity: 0.8348533511161804
#              created_at                                    texts_by_minute  \
# 0   2022-12-15 01:00:00  [, , , , , , , , , , , , , さあ、今夜も お願いします！ お願いし...
# 1   2022-12-15 01:01:00  [  ,   遅延, , , , , , , , こんなんなんぼあってもいいですからね  ,...
# 2   2022-12-15 01:02:00  [, 森高千里さんから可愛いをいただいた久保ちゃん(笑) 可愛いなんてなんぼ言われてもいいよ...
# 3   2022-12-15 01:03:00  [やかましいわ , 久保ちゃん、それ聞いちゃおしまいよ ,  頑張っちゃってください, クリ...
# 4   2022-12-15 01:04:00  [あの森高千里さんから「かわいい」頂きましたｗ  ,  クリスマスツリーとシュトーレンを買う...
# ..                  ...                                                ...
# 120 2022-12-15 03:00:00  [今週もお疲れ様でした！ かっこつけようとして、失敗してしまったのがくぼちゃんらしいです笑 ...
# 121 2022-12-15 03:01:00  [『乃木坂46のオールナイトニッポン』、卒業を発表している齋藤飛鳥の生出演が決定！  パーソ...
# 122 2022-12-15 03:02:00  [またねー  , しおりんお疲れ様でした〜！ 来週も絶対聴く！👂 またね〜(´▽`)ﾉ   ...
# 123 2022-12-15 03:03:00  [敗者復活でやるような場所じゃない , 久保ちゃんお疲れ様でした🎵 ソロはひさびさでしたね ...
# 124 2022-12-15 03:04:00  [しおりさん、スタッフさんオツカレサマデシタ！！ 久々の1人喋りスポーツの話満載でしたが色ん...
#
#      average_similarity
# 0              0.977954
# 1              0.864120
# 2              0.738300
# 3              0.669687
# 4              0.726158
# ..                  ...
# 120            0.814245
# 121            0.742052
# 122            0.784267
# 123            0.683805
# 124            0.834853
#
# [125 rows x 3 columns]

# %%
df_texts_by_minute.to_csv('cosine_similarity_221214_ann_wed.csv', index=False)
